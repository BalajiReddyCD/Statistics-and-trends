# %%
#importing necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#Read the csv file which I've taken from kaggle
df = pd.read_csv("C:/Users/BALA/OneDrive - University of Hertfordshire (1)/output.csv")
df
# Out:
#             brand           model transmission  age    fuel  engine       km  \
# 0        mahindra            thar       manual  4.0  diesel  2184.0  11003.0
# 1         hyundai           verna       manual  6.0  petrol  1591.0  66936.0
# 2            tata         harrier       manual  2.0  diesel  1956.0  27990.0
# 3           honda            city    automatic  1.0  petrol  1498.0   5061.0
# 4            ford        ecosport       manual  3.0  diesel  1498.0  23480.0
# ...           ...             ...          ...  ...     ...     ...      ...
# 32195      datsun         redi go       manual  6.0  petrol     NaN  11500.0
# 32196      toyota           yaris       manual  6.0  petrol     NaN  73393.0
# 32197  volkswagen            ameo       manual  8.0  petrol     NaN  83810.0
# 32198     hyundai  grand i10 nios    automatic  5.0  petrol     NaN  39162.0
# 32199        tata           tigor       manual  2.0  petrol     NaN  82009.0
#
#        owner      price       location  mileage  power  seats       type
# 0        1.0  1231000.0            NaN      NaN    NaN    NaN        NaN
# 1        1.0   786000.0            NaN      NaN    NaN    NaN        NaN
# 2        1.0  1489000.0            NaN      NaN    NaN    NaN        NaN
# 3        1.0  1227000.0            NaN      NaN    NaN    NaN        NaN
# 4        1.0   887000.0            NaN      NaN    NaN    NaN        NaN
# ...      ...        ...            ...      ...    ...    ...        ...
# 32195    1.0   292000.0    maharashtra      NaN    NaN    5.0  hatchback
# 32196    2.0   534000.0      karnataka      NaN    NaN    5.0      sedan
# 32197    2.0   424000.0  uttar pradesh      NaN    NaN    5.0      sedan
# 32198    1.0   685000.0     chandigarh      NaN    NaN    5.0  hatchback
# 32199    2.0   392000.0    maharashtra      NaN    NaN    5.0      sedan
#
# [32200 rows x 14 columns]

# %%
# Describing the data for better understanding
desc_stats = df.describe()
print("Summary Statistics:\n", desc_stats)
# Out:
# Summary Statistics:
#                  age        engine            km         owner         price  \
# count  32199.000000  24068.000000  3.220000e+04  16819.000000  3.220000e+04
# mean       7.120625   1489.872569  5.495269e+04      1.263452  7.347001e+05
# std        3.485577    520.916872  5.577145e+04      0.490463  7.037702e+05
# min        0.000000     72.000000  0.000000e+00      1.000000  4.000000e+04
# 25%        4.000000   1197.000000  3.020825e+04      1.000000  3.850000e+05
# 50%        7.000000   1248.000000  5.000000e+04      1.000000  5.510000e+05
# 75%        9.000000   1591.000000  7.102075e+04      1.000000  7.920000e+05
# max       29.000000   5998.000000  6.500000e+06      4.000000  7.066000e+06
#
#             mileage         power         seats
# count  21380.000000  21273.000000  29353.000000
# mean      19.305532    103.497647      5.233537
# std        4.418605     45.002260      0.707639
# min        0.000000     34.200000      0.000000
# 25%       16.500000     74.000000      5.000000
# 50%       19.010000     88.500000      5.000000
# 75%       22.320000    120.000000      5.000000
# max       46.620600    600.000000     10.000000

# %%
#Summary of the we've data taken
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32200 entries, 0 to 32199
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         32199 non-null  object
#  1   model         32199 non-null  object
#  2   transmission  32200 non-null  object
#  3   age           32199 non-null  float64
#  4   fuel          32200 non-null  object
#  5   engine        24068 non-null  float64
#  6   km            32200 non-null  float64
#  7   owner         16819 non-null  float64
#  8   price         32200 non-null  float64
#  9   location      13801 non-null  object
#  10  mileage       21380 non-null  float64
#  11  power         21273 non-null  float64
#  12  seats         29353 non-null  float64
#  13  type          8015 non-null   object
# dtypes: float64(8), object(6)
# memory usage: 3.4+ MB

# %%
# Check the number of null values in each column
null_values = df.isnull().sum()
print(null_values)
# Out:
# brand               1
# model               1
# transmission        0
# age                 1
# fuel                0
# engine           8132
# km                  0
# owner           15381
# price               0
# location        18399
# mileage         10820
# power           10927
# seats            2847
# type            24185
# dtype: int64

# %%
# Removing cols which have mostly empty values, which doesn't make any difference to the data
df = df.drop(['engine', 'owner', 'location', 'mileage', 'power', 'seats', 'type'], axis=1)

# %%
# Dropping null values
df = df.dropna()

# %%
# Checking df after cleaning
df
# Out:
#             brand           model transmission  age    fuel       km  \
# 0        mahindra            thar       manual  4.0  diesel  11003.0
# 1         hyundai           verna       manual  6.0  petrol  66936.0
# 2            tata         harrier       manual  2.0  diesel  27990.0
# 3           honda            city    automatic  1.0  petrol   5061.0
# 4            ford        ecosport       manual  3.0  diesel  23480.0
# ...           ...             ...          ...  ...     ...      ...
# 32195      datsun         redi go       manual  6.0  petrol  11500.0
# 32196      toyota           yaris       manual  6.0  petrol  73393.0
# 32197  volkswagen            ameo       manual  8.0  petrol  83810.0
# 32198     hyundai  grand i10 nios    automatic  5.0  petrol  39162.0
# 32199        tata           tigor       manual  2.0  petrol  82009.0
#
#            price
# 0      1231000.0
# 1       786000.0
# 2      1489000.0
# 3      1227000.0
# 4       887000.0
# ...          ...
# 32195   292000.0
# 32196   534000.0
# 32197   424000.0
# 32198   685000.0
# 32199   392000.0
#
# [32199 rows x 7 columns]

# %%
# Calculate correlation matrix with only numeric columns
correlation_matrix = df.select_dtypes(include=['float64', 'int64']).corr()
print("\nCorrelation Matrix:\n", correlation_matrix)
# Out:
# Correlation Matrix:
#                age    engine        km     owner     price   mileage     power  \
# age      1.000000  0.142628  0.250923  0.187501 -0.206513 -0.309554  0.070522
# engine   0.142628  1.000000  0.156273  0.013713  0.628310 -0.616014  0.825400
# km       0.250923  0.156273  1.000000  0.086191 -0.045677 -0.088618  0.048925
# owner    0.187501  0.013713  0.086191  1.000000 -0.119357 -0.152321  0.019546
# price   -0.206513  0.628310 -0.045677 -0.119357  1.000000 -0.322014  0.769534
# mileage -0.309554 -0.616014 -0.088618 -0.152321 -0.322014  1.000000 -0.532878
# power    0.070522  0.825400  0.048925  0.019546  0.769534 -0.532878  1.000000
# seats    0.007917  0.515536  0.139800 -0.007996  0.154632 -0.392785  0.163542
#
#             seats
# age      0.007917
# engine   0.515536
# km       0.139800
# owner   -0.007996
# price    0.154632
# mileage -0.392785
# power    0.163542
# seats    1.000000

# %%
top_brands = df['brand'].value_counts().nlargest(5)
print(top_brands)
# Out:
# brand
# maruti      10561
# hyundai      6757
# honda        3198
# mahindra     1550
# toyota       1413
# Name: count, dtype: int64

# %%
# Function to plot the top 5 car brands
def plot_top_brands(df):
    top_brands = df['brand'].value_counts().nlargest(5)

    plt.figure(figsize=(10, 6))
    sns.barplot(x=top_brands.index, y=top_brands.values, hue=top_brands.index, palette="viridis", dodge=False, legend=False)
    plt.title("Top 5 Most Common Car Brands")
    plt.xlabel("Brand")
    plt.ylabel("Count")
    plt.show()

# Call the function to plot
plot_top_brands(df)

# %%
# Function to plot the line graph
def plot_age_vs_top_brands(df):
    # Calculate the top 10 most common brands
    top_brands = df['brand'].value_counts().nlargest(10).index.tolist()
    
    # Filter the DataFrame for only top brands
    filtered_df = df[df['brand'].isin(top_brands)]
    
    # Calculate the average age for each brand
    average_age = filtered_df.groupby('brand')['age'].mean().reset_index()
    
    # Sort by age for better line plotting
    average_age = average_age.sort_values(by='brand')
    
    # Plotting the line graph
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=average_age, x='brand', y='age', marker='o') 
    plt.title("Average Age of Top 10 Car Brands")
    plt.xlabel("Car Brand")
    plt.ylabel("Average Age (Years)")
    plt.xticks(rotation=45)
    plt.grid()
    plt.show()

# Call the function to plot
plot_age_vs_top_brands(df)

# %%
# Function to plot correlation heatmap
def plot_correlation_heatmap(corr_matrix):
    plt.figure(figsize=(10, 6))
    sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", square=True)
    plt.title("Correlation Heatmap of Numeric Features")
    plt.show()

# Call the function to plot the heatmap
plot_correlation_heatmap(correlation_matrix)
